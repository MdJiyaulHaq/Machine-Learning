# %% [markdown]
# Visualize Distributions With Seaborn
#
# Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.

# %%
import numpy as np
from numpy import random

x= random.normal(size=(3))
y = random.normal(size=(2, 3))
print(x)
print(y)

# %%
z = random.normal(loc=2, scale=3, size=(4,3))
z

# %% [markdown]
# loc - (Mean) where the peak of the bell exists.
#
# scale - (Standard Deviation) how flat the graph distribution should be.
#
# size - The shape of the returned array.

# %% [markdown]
# # visualization of normal distribution

# %%
import numpy as np
import seaborn as sns
from numpy import random
import matplotlib.pyplot as plt

x = random.normal(size=(12,11))
sns.distplot(x, hist=False)
plt.show()
# Out:
# /home/md/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #kNote: The curve of a Normal Distribution is also known as the Bell Curve.
#       It is because of the bell-shaped curve.
